# %%
import pandas as pd   # Great for tables (google spreadsheets, microsoft excel, csv). 
import os # Good for navigating your computer's files 
import gdown
gdown.download('https://drive.google.com/uc?id=1nDjHLBMBZ3THSck1Ah3XyhgtRHIBT2Ec', 'dekho.csv', True)
# Out:
# 'dekho.csv'

# %%
data_path  = 'dekho.csv'
car_data = pd.read_csv(data_path)
car_data.head()
# Out:
#   Car_Name  Age  Selling_Price  Kms_Driven Fuel_Type Seller_Type Transmission
# 0     ritz    5           3.35       27000    Petrol      Dealer       Manual
# 1      sx4    6           4.75       43000    Diesel      Dealer       Manual
# 2     ciaz    2           7.25        6900    Petrol      Dealer       Manual
# 3  wagon r    8           2.85        5200    Petrol      Dealer       Manual
# 4    swift    5           4.60       42450    Diesel      Dealer       Manual

# %%
car_data[['Fuel_Type']].head()
# Out:
#   Fuel_Type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Petrol
# 4    Diesel

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x = 'Kms_Driven', y = 'Selling_Price', data = car_data)
# Out:
# <AxesSubplot:xlabel='Kms_Driven', ylabel='Selling_Price'>

# %%
car_data.groupby('Transmission').count()
# Out:
#               Car_Name  Age  Selling_Price  Kms_Driven  Fuel_Type  Seller_Type
# Transmission
# Automatic           40   40             40          40         40           40
# Manual             261  261            261         261        261          261

# %%
sns.catplot(x='Fuel_Type',y='Selling_Price',data=car_data,kind='swarm')
# Out:
# /Users/jeffk/Library/Python/3.8/lib/python/site-packages/seaborn/categorical.py:1296: UserWarning: 31.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='Transmission',y='Selling_Price',data=car_data,kind='swarm')
# Out:
# /Users/jeffk/Library/Python/3.8/lib/python/site-packages/seaborn/categorical.py:1296: UserWarning: 15.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn import linear_model
import numpy as np

x = car_data[['Age']]
y = car_data[['Selling_Price']]
l = linear_model.LinearRegression(fit_intercept=True)
l.fit(x,y)

y_pred = l.predict(x)
plt.plot(x, y_pred, color='red')

plt.scatter(x, y)
plt.xlabel('Age') # set the labels of the x and y axes
plt.ylabel('Selling_Price (lakhs)')
plt.show()
